# %% [markdown]
# <a href="https://colab.research.google.com/github/sundarp17/sundar_info5731_fall2020/blob/master/In_class_exercise_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (9/16/2020, 20 points in total)

# %% [markdown]
# The purpose of this exercise is to under users' information needs, then collect the data for analysis.

# %% [markdown]
# Question 1 (8 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

The research or practical question that I have in my mind is how to invest in stock market, so that we can gain profits. 
In order to tell that, we need the data of the active stocks, stock gainers, and stock losers,, so that we can perform some 
analysis on the companies who are active, in profits, and in loss. To perform the analysis, we need a lot of data. we need to 
analyse atleast the last 3 months of the stock data of the respective companies. The website yahoo finance provides us the
insights of active stocks, stock gainers, and stock losers. So, I webscraped the yahoo finance website.

The steps for collecting and saving the data are as follows:

1) Analyse whether the website is static or dynamic(using the inspect element).
2) If it is static, then use beautiful soup or else use selenium web driver.
3) The yahoo finance is static website, so I used beautiful soup.
4) Make a list of items you want to collect.
5) I want to collect the symbol, name, price, change, % change, volume, avg vol for 3 months, market cap
6) By using the inspect element, get the class and the tag of the respective item.
7) Create a empty list for each items.
8) You can append the data into the empty list or you can insert the data into dataframe by creating empty df first and then use the append mode if you 
   want to web scrape multiple web pages.
9) Convert the data frame into csv with the help of pandas.





'''

# %% [markdown]
# Question 2 (12 points): Write python code to collect 500 items of the data you plan to collect above.

# %%
# You code here (Please add comments in the code):
#most active stocks

#import the necessary modules
import requests
from bs4 import BeautifulSoup
import pandas as pd

#creating functions for each item that we want to scrap
def symbol(soup):
    symbols=[]
    for sym in soup.find_all(name="tr",attrs={"class":"simpTblRow"}): #getting the tag tr with class simpTBlRow
        for symb in sym.find_all('td', attrs={'aria-label': 'Symbol'}): #get the data of the td tag if the aria-label is a symbol
            symbols.append(symb.text)
    return symbols
def name(soup):
    names=[]
    for i in soup.find_all(name="tr",attrs={"class":"simpTblRow"}):
        for j in i.find_all('td', attrs={'aria-label': 'Name'}):
            names.append(j.text)
    return names
def price(soup):
    prices=[]
    for i in soup.find_all(name="tr",attrs={"class":"simpTblRow"}):
        for j in i.find_all('td', attrs={'aria-label': 'Price (Intraday)'}):
            prices.append(j.text)
    return prices
def change(soup):
    changes=[]
    for i in soup.find_all(name="tr",attrs={"class":"simpTblRow"}):
        for j in i.find_all('td', attrs={'aria-label': 'Change'}):
            changes.append(j.text)
    return changes
def percent_change(soup):
    per_change=[]
    for i in soup.find_all(name="tr",attrs={"class":"simpTblRow"}):
        for j in i.find_all('td', attrs={'aria-label': '% Change'}):
            per_change.append(j.text)
    return per_change
def volume(soup):
    vol=[]
    for i in soup.find_all(name="tr",attrs={"class":"simpTblRow"}):
        for j in i.find_all('td', attrs={'aria-label': 'Volume'}):
            vol.append(j.text)
    return vol
def avg_vol_3months(soup):
    avg_vol=[]
    for i in soup.find_all(name="tr",attrs={"class":"simpTblRow"}):
        for j in i.find_all('td', attrs={'aria-label': 'Avg Vol (3 month)'}):
            avg_vol.append(j.text)
    return avg_vol
def market_cap(soup):
    market=[]
    for i in soup.find_all(name="tr",attrs={"class":"simpTblRow"}):
        for j in i.find_all('td', attrs={'aria-label': 'Market Cap'}):
            market.append(j.text)
    return market


urls=['https://finance.yahoo.com/most-active?offset=0&count=100','https://finance.yahoo.com/most-active?count=100&offset=100',
      'https://finance.yahoo.com/most-active?count=100&offset=200'] #give the urls for the websites you want to scrap

s=[]
n=[]
p=[]
c=[]
pc=[]
v=[]
av=[]
mc=[]

#creating a empty dataframe and converting it into csv
dfObj=pd.DataFrame(columns=['Symbol','Name','Price','Change','% Change','Volume','Avg Vol(3 months)','Market Cap'])
ex=pd.DataFrame(dfObj).to_csv('stocks.csv',header=True,index=None)
for i in urls:
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'}
    r = requests.get(i, headers=headers) #getting the data from the url using requests
    soup = BeautifulSoup(r.content, 'lxml')
    s=(symbol(soup))
    n=(name(soup))
    p=(price(soup))
    c=(change(soup))
    pc=(percent_change(soup))
    v=(volume(soup))
    av=(avg_vol_3months(soup))
    mc=(market_cap(soup))
    zippedList=list(zip(s,n,p,c,pc,v,av,mc))
    dfObj=pd.DataFrame(zippedList,columns=['Symbol','Name','Price','Change','% Change','Volume','Avg Vol(3 months)','Market Cap'])
    ex=pd.DataFrame(dfObj).to_csv('stocks.csv',header=False,index=None,mode='a')
dfObj
# Out:
#    Symbol                               Name  ... Avg Vol(3 months) Market Cap
# 0     HBI                   Hanesbrands Inc.  ...            6.795M     5.644B
# 1     LYG           Lloyds Banking Group plc  ...            5.854M    24.519B
# 2    EXEL                     Exelixis, Inc.  ...            2.118M     8.697B
# 3     CRM               salesforce.com, inc.  ...            7.993M   228.155B
# 4     HRB                    H&R Block, Inc.  ...            3.625M     2.872B
# 5     PSX                        Phillips 66  ...            3.275M    26.425B
# 6     EOG                EOG Resources, Inc.  ...            4.202M    24.105B
# 7    SPOT            Spotify Technology S.A.  ...            2.952M    43.996B
# 8    AMCR                          Amcor plc  ...            9.544M    17.476B
# 9      CI                  Cigna Corporation  ...            1.868M    62.916B
# 10    WDC        Western Digital Corporation  ...            6.028M    12.091B
# ...

# %%
#stock gainers
urls_gainers=['https://finance.yahoo.com/gainers']


s=[]
n=[]
p=[]
c=[]
pc=[]
v=[]
av=[]
mc=[]
for i in urls_gainers:
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'}
    r = requests.get(i, headers=headers) #getting the data from the url using requests
    soup = BeautifulSoup(r.content, 'lxml')
    s=(symbol(soup))
    n=(name(soup))
    p=(price(soup))
    c=(change(soup))
    pc=(percent_change(soup))
    v=(volume(soup))
    av=(avg_vol_3months(soup))
    mc=(market_cap(soup))
    zippedList=list(zip(s,n,p,c,pc,v,av,mc))
    dfObj=pd.DataFrame(zippedList,columns=['Symbol','Name','Price','Change','% Change','Volume','Avg Vol(3 months)','Market Cap'])
    ex=pd.DataFrame(dfObj).to_csv('stocks_gainers.csv',header=False,index=None,mode='a')
dfObj
# Out:
#    Symbol                              Name  ... Avg Vol(3 months) Market Cap
# 0    SRNE       Sorrento Therapeutics, Inc.  ...           40.851M     2.585B
# 1    JOBS                       51job, Inc.  ...           143,490     5.319B
# 2    PENN        Penn National Gaming, Inc.  ...            9.531M     10.62B
# 3   BYDDY               BYD Company Limited  ...           132,778    42.479B
# 4   BYDDF               BYD Company Limited  ...           320,320    42.367B
# 5    MRCY             Mercury Systems, Inc.  ...           448,146     4.093B
# 6     EAF       GrafTech International Ltd.  ...            1.683M     2.079B
# 7     RDY  Dr. Reddy's Laboratories Limited  ...           157,204    10.943B
# 8    PCVX                     Vaxcyte, Inc.  ...           152,960     2.802B
# 9      GE          General Electric Company  ...           83.671M    61.886B
# 10   AHCO                 AdaptHealth Corp.  ...           362,378     2.018B
# ...

# %%
#stock loss
url_loss=['https://finance.yahoo.com/losers?offset=0&count=100']

s=[]
n=[]
p=[]
c=[]
pc=[]
v=[]
av=[]
mc=[]
for i in url_loss:
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'}
    r = requests.get(i, headers=headers) #getting the data from the url using requests
    soup = BeautifulSoup(r.content, 'lxml')
    s=(symbol(soup))
    n=(name(soup))
    p=(price(soup))
    c=(change(soup))
    pc=(percent_change(soup))
    v=(volume(soup))
    av=(avg_vol_3months(soup))
    mc=(market_cap(soup))
    zippedList=list(zip(s,n,p,c,pc,v,av,mc))
    dfObj=pd.DataFrame(zippedList,columns=['Symbol','Name','Price','Change','% Change','Volume','Avg Vol(3 months)','Market Cap'])
    ex=pd.DataFrame(dfObj).to_csv('stocks_loss.csv',header=False,index=None,mode='a')
dfObj
# Out:
#    Symbol                                  Name  ... Avg Vol(3 months) Market Cap
# 0   QRTEB                   Qurate Retail, Inc.  ...            35,200     5.277B
# 1    FSLR                     First Solar, Inc.  ...            1.504M     7.355B
# 2     INO          Inovio Pharmaceuticals, Inc.  ...           33.266M     2.793B
# 3    CRNC                          Cerence Inc.  ...           963,459     2.065B
# 4    BEKE                      KE Holdings Inc.  ...            6.894M    64.266B
# ..    ...                                   ...  ...               ...        ...
# 95   XPEV                            XPeng Inc.  ...           17.153M    14.747B
# 96   PRLB                      Proto Labs, Inc.  ...           271,912     3.949B
# 97    BLD                        TopBuild Corp.  ...           450,673     5.317B
# 98    MGM             MGM Resorts International  ...           20.683M    11.079B
# ...
